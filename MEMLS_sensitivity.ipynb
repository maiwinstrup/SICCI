# %% [markdown]
# # Sensitivity study of the MEMLS physical radiation model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import memls_functions as memls
import setupmodel

# %% [markdown]
# ## Set input parameters:

# %%
# Parameters are:
# Snow thickness
# Ice thickness
# Temperature
# Salinity
# Wetness
# Density
# Correlation length (scattering)
# Thickness
# Sea ice type

hsnow = 0.3 # snow thickness [m]
hice = 3.0 # ice thickness [m]
nsnow = 10 # number of layers in snow
nice = 20 # number of layers in ice

Ta = 273.0-10 # Surface temperature, K
sal_snowice_surface = 0.0 # Salinity at the surface of the ice 
sal_ice_bottom = 3.0; # Salinity of the bottom ice [ppt]

rho_snow = 360.0 # Estimate from paper

pcc_snow_top=0.07; # Correlation length of new snow [mm]
pcc_snow_bottom=0.3; # Correlation length of old snow [mm] - not used???! 
pcc_ice=1.5; # Correlation length of multiyear ice [mm]

modelgrid, T, salinity, rho, pcc, sitype, si, Wi, num, di = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)

# Calculate Tb at following frequencies:
freqs= [1.4, 6.9, 10.7, 18.7, 23.8, 36.5, 50.0, 89.0]

# %% [markdown]
# ## Testing impact of snow thickness

# %%
plt.figure(figsize=(12, 5))

for hsnow in np.arange(0.1,0.5,0.1):
    print 'hsnow', hsnow
    
    modelgrid, T, salinity, rho, pcc = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)
    frequency, eh, ev, TBH, TBV, TeffH, TeffV, pend_h, pend_v = memls.memls_mod(freqs,np.array(num),di,T,Wi,rho,pcc,salinity,sitype,si)
    
    plt.subplot(1,2,1)
    plt.plot(frequency,TBH,'.-b')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbh')
    plt.subplot(1,2,2)
    plt.plot(frequency,TBV,'.-r')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbv')

plt.show()
# Out:
# hsnow 0.1
# hsnow 0.2
# hsnow 0.3
# hsnow 0.4

# %% [markdown]
# ## Testing impact of ice thickness

# %%
hsnow = 0.3 # snow thickness [m]
hice = 3.0 # ice thickness [m]
nsnow = 10 # number of layers in snow
nice = 20 # number of layers in ice
Ta = 273.0-10 # Surface temperature, K
sal_snowice_surface = 0.0 # Salinity at the surface of the ice 
sal_ice_bottom = 3.0; # Salinity of the bottom ice [ppt]
rho_snow = 360.0 # Estimate from paper
pcc_snow_top=0.07; # Correlation length of new snow [mm]
pcc_snow_bottom=0.3; # Correlation length of old snow [mm] - not used???! 
pcc_ice=1.5; # Correlation length of multiyear ice [mm]


plt.figure(figsize=(12, 5))

for hice in np.arange(0.1,3,0.2):
    print 'hice', hice
    
    modelgrid, T, salinity, rho, pcc = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)
    frequency, eh, ev, TBH, TBV, TeffH, TeffV, pend_h, pend_v = memls.memls_mod(freqs,np.array(num),di,T,Wi,rho,pcc,salinity,sitype,si)
    
    plt.subplot(1,2,1)
    plt.plot(frequency,TBH,'.-b')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbh')
    plt.subplot(1,2,2)
    plt.plot(frequency,TBV,'.-r')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbv')

plt.show()
# Out:
# hice 0.1
# hice 0.3
# hice 0.5
# hice 0.7
# hice 0.9
# hice 1.1
# hice 1.3
# hice 1.5
# hice 1.7
# hice 1.9
# hice 2.1
# hice 2.3
# hice 2.5
# hice 2.7
# hice 2.9

# %% [markdown]
# ## Testing impact of surface temperature

# %%
hsnow = 0.3 # snow thickness [m]
hice = 3.0 # ice thickness [m]
nsnow = 10 # number of layers in snow
nice = 20 # number of layers in ice
Ta = 273.0-10 # Surface temperature, K
sal_snowice_surface = 0.0 # Salinity at the surface of the ice 
sal_ice_bottom = 3.0; # Salinity of the bottom ice [ppt]
rho_snow = 360.0 # Estimate from paper
pcc_snow_top=0.07; # Correlation length of new snow [mm]
pcc_snow_bottom=0.3; # Correlation length of old snow [mm] - not used???! 
pcc_ice=1.5; # Correlation length of multiyear ice [mm]

plt.figure(figsize=(12, 5))

for Ta in np.arange(250.,270.,5.):
    print 'Ta', Ta
    modelgrid, T, salinity, rho, pcc = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)
    frequency, eh, ev, TBH, TBV, TeffH, TeffV, pend_h, pend_v = memls.memls_mod(freqs,np.array(num),di,T,Wi,rho,pcc,salinity,sitype,si)
    
    plt.subplot(1,2,1)
    plt.plot(frequency,TBH,'.-b')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbh')
    plt.subplot(1,2,2)
    plt.plot(frequency,TBV,'.-r')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbv')

plt.show()
# Out:
# Ta 250.0
# Ta 255.0
# Ta 260.0
# Ta 265.0

# %% [markdown]
# ## Testing impact of salinity at snow/ice interface

# %%
hsnow = 0.3 # snow thickness [m]
hice = 3.0 # ice thickness [m]
nsnow = 10 # number of layers in snow
nice = 20 # number of layers in ice
Ta = 273.0-10 # Surface temperature, K
sal_snowice_surface = 0.0 # Salinity at the surface of the ice 
sal_ice_bottom = 3.0; # Salinity of the bottom ice [ppt]
rho_snow = 360 # Estimate from paper
pcc_snow_top=0.07; # Correlation length of new snow [mm]
pcc_snow_bottom=0.3; # Correlation length of old snow [mm] - not used???! 
pcc_ice=1.5; # Correlation length of multiyear ice [mm]

plt.figure(figsize=(12, 5))

for sal_snow_ice_surface in np.arange(0,2,0.5):
    print 'sal_snow_ice_surface', sal_snow_ice_surface
    modelgrid, T, salinity, rho, pcc = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)
    frequency, eh, ev, TBH, TBV, TeffH, TeffV, pend_h, pend_v = memls.memls_mod(freqs,np.array(num),di,T,Wi,rho,pcc,salinity,sitype,si)
    
    plt.subplot(1,2,1)
    plt.plot(frequency,TBH,'.-b')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbh')
    plt.subplot(1,2,2)
    plt.plot(frequency,TBV,'.-r')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbv')

plt.show()
# Out:
# sal_snow_ice_surface 0.0
# sal_snow_ice_surface 0.5
# sal_snow_ice_surface 1.0
# sal_snow_ice_surface 1.5

# %% [markdown]
# ## Testing impact of salinity at bottom of ice

# %%
hsnow = 0.3 # snow thickness [m]
hice = 3.0 # ice thickness [m]
nsnow = 10 # number of layers in snow
nice = 20 # number of layers in ice
Ta = 273.0-10 # Surface temperature, K
sal_snowice_surface = 0.0 # Salinity at the surface of the ice 
sal_ice_bottom = 3.0; # Salinity of the bottom ice [ppt]
rho_snow = 360.0 # Estimate from paper
pcc_snow_top=0.07; # Correlation length of new snow [mm]
pcc_snow_bottom=0.3; # Correlation length of old snow [mm] - not used???! 
pcc_ice=1.5; # Correlation length of multiyear ice [mm]

plt.figure(figsize=(12, 5))

for sal_ice_bottom in np.arange(2.0,5.0,0.5):
    print 'sal_ice_bottom', sal_ice_bottom
    modelgrid, T, salinity, rho, pcc = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)
    frequency, eh, ev, TBH, TBV, TeffH, TeffV, pend_h, pend_v = memls.memls_mod(freqs,np.array(num),di,T,Wi,rho,pcc,salinity,sitype,si)
    
    plt.subplot(1,2,1)
    plt.plot(frequency,TBH,'.-b')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbh')
    plt.subplot(1,2,2)
    plt.plot(frequency,TBV,'.-r')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbv')

plt.show()
# Out:
# sal_ice_bottom 2.0
# sal_ice_bottom 2.5
# sal_ice_bottom 3.0
# sal_ice_bottom 3.5
# sal_ice_bottom 4.0
# sal_ice_bottom 4.5

# %% [markdown]
# ## Testing impact of snow density

# %%
hsnow = 0.3 # snow thickness [m]
hice = 3.0 # ice thickness [m]
nsnow = 10 # number of layers in snow
nice = 20 # number of layers in ice
Ta = 273.0-10 # Surface temperature, K
sal_snowice_surface = 0.0 # Salinity at the surface of the ice 
sal_ice_bottom = 3.0; # Salinity of the bottom ice [ppt]
rho_snow = 360 # Estimate from paper
pcc_snow_top=0.07; # Correlation length of new snow [mm]
pcc_snow_bottom=0.3; # Correlation length of old snow [mm] - not used???! 
pcc_ice=1.5; # Correlation length of multiyear ice [mm]

plt.figure(figsize=(12, 5))

for rho_snow in np.arange(260.0,460.0,50):
    print 'rho_snow', rho_snow
    modelgrid, T, salinity, rho, pcc = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)
    frequency, eh, ev, TBH, TBV, TeffH, TeffV, pend_h, pend_v = memls.memls_mod(freqs,np.array(num),di,T,Wi,rho,pcc,salinity,sitype,si)
    
    plt.subplot(1,2,1)
    plt.plot(frequency,TBH,'.-b')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbh')
    plt.subplot(1,2,2)
    plt.plot(frequency,TBV,'.-r')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbv')

plt.show()
# Out:
# rho_snow 260.0
# rho_snow 310.0
# rho_snow 360.0
# rho_snow 410.0

# %% [markdown]
# ## Testing impact of scattering in surface snow

# %%
hsnow = 0.3 # snow thickness [m]
hice = 3.0 # ice thickness [m]
nsnow = 10 # number of layers in snow
nice = 20 # number of layers in ice
Ta = 273.0-10 # Surface temperature, K
sal_snowice_surface = 0.0 # Salinity at the surface of the ice 
sal_ice_bottom = 3.0; # Salinity of the bottom ice [ppt]
rho_snow = 360.0 # Estimate from paper
pcc_snow_top=0.07; # Correlation length of new snow [mm]
pcc_snow_bottom=0.3; # Correlation length of old snow [mm] - not used???! 
pcc_ice=1.5; # Correlation length of multiyear ice [mm]

plt.figure(figsize=(12, 5))

for pcc_snow_top in np.arange(0.03,0.1,0.01):
    print 'pcc_snow_top', pcc_snow_top
    modelgrid, T, salinity, rho, pcc = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)
    frequency, eh, ev, TBH, TBV, TeffH, TeffV, pend_h, pend_v = memls.memls_mod(freqs,np.array(num),di,T,Wi,rho,pcc,salinity,sitype,si)
    
    plt.subplot(1,2,1)
    plt.plot(frequency,TBH,'.-b')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbh')
    plt.subplot(1,2,2)
    plt.plot(frequency,TBV,'.-r')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbv')

plt.show()
# Out:
# pcc_snow_top 0.03
# pcc_snow_top 0.04
# pcc_snow_top 0.05
# pcc_snow_top 0.06
# pcc_snow_top 0.07
# pcc_snow_top 0.08
# pcc_snow_top 0.09
# pcc_snow_top 0.1

# %% [markdown]
# ## Testing impact of scattering in ice:

# %%
hsnow = 0.3 # snow thickness [m]
hice = 3.0 # ice thickness [m]
nsnow = 10 # number of layers in snow
nice = 20 # number of layers in ice
Ta = 273.0-10 # Surface temperature, K
sal_snowice_surface = 0.0 # Salinity at the surface of the ice 
sal_ice_bottom = 3.0; # Salinity of the bottom ice [ppt]
rho_snow = 360.0 # Estimate from paper
pcc_snow_top=0.07; # Correlation length of new snow [mm]
pcc_snow_bottom=0.3; # Correlation length of old snow [mm] - not used???! 
pcc_ice=1.5; # Correlation length of multiyear ice [mm]

plt.figure(figsize=(12, 5))

for pcc_ice in np.arange(1.,2.5,0.25):
    print 'pcc_ice', pcc_ice
    modelgrid, T, salinity, rho, pcc = setupmodel.setupmodel(hsnow,hice,nsnow,nice,Ta,sal_snowice_surface,sal_ice_bottom,rho_snow,pcc_snow_top,pcc_snow_bottom,pcc_ice)
    frequency, eh, ev, TBH, TBV, TeffH, TeffV, pend_h, pend_v = memls.memls_mod(freqs,np.array(num),di,T,Wi,rho,pcc,salinity,sitype,si)
    
    plt.subplot(1,2,1)
    plt.plot(frequency,TBH,'.-b')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbh')
    plt.subplot(1,2,2)
    plt.plot(frequency,TBV,'.-r')
    plt.xlabel('Frequency, GHz')
    plt.ylabel('Tbv')

plt.show()
# Out:
# pcc_ice 1.0
# pcc_ice 1.25
# pcc_ice 1.5
# pcc_ice 1.75
# pcc_ice 2.0
# pcc_ice 2.25

# %% [markdown]
# ## Conclusion:
# Factors that matter: hsnow, hice, Ts, salinity at bottom of ice
#
# Factors that don't matter: salinity at snow/ice interface, rho_snow, pcc_snow, pcc_ice
